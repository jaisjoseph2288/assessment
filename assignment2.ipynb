# %% [markdown]
# <a href="https://colab.research.google.com/github/jaisjoseph2288/assessment/blob/main/assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_excel('/iris.xls')
data.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
#Display the columns in the dataset.
print(data.keys())
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
#Calculate the mean of each column of the dataset.
numeric_cols = ['SL', 'SW', 'PL', 'PW']

for i in numeric_cols:
  total_sum = sum(data[i])
  count = len(data[i])
  mean_val = total_sum / count
  print(f'Mean of {i}: {mean_val:.4f}')
# Out:
# Mean of SL: 5.8433
# Mean of SW: 3.0540
# Mean of PL: 3.7587
# Mean of PW: 1.1987

# %%
#Check for the null values present in the dataset.
print(data.isna().any())
print(data.isna().any().any())
# Out:
# SL                False
# SW                False
# PL                False
# PW                False
# Classification    False
# dtype: bool
# False

# %%
data.hist(figsize=(8, 6))
# Out:
# array([[<Axes: title={'center': 'SL'}>, <Axes: title={'center': 'SW'}>],
#        [<Axes: title={'center': 'PL'}>, <Axes: title={'center': 'PW'}>]],
#       dtype=object)

# %%
import seaborn as sns

sns.scatterplot(data=data, x='PL', y='PW', hue='Classification')
# Out:
# <Axes: xlabel='PL', ylabel='PW'>

# %%
import seaborn as sns

sns.boxplot(data=data, x='Classification', y='PL')
# Out:
# <Axes: xlabel='Classification', ylabel='PL'>
